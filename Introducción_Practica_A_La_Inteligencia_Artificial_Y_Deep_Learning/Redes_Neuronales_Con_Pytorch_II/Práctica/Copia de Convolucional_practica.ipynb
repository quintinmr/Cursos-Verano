# %% [markdown]
# # Creación de redes neuronales convolucionales
#
# En esta práctica vamos a centrarnos en crear dos redes neuronales tipo Alexnet y VGG16 para la clasificación de aceitunas, y para identificación de variedades.

# %% [markdown]
# ## Carga de librerías y datos
#
# Comenzamos, como otras veces, con el preámbulo; cargamos las librerías que vamos a utilizar en este notebook.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torchvision.transforms as T
from torch import optim

# %%
# !nvidia-smi
# Out:
# Wed Aug 17 11:57:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Y descargamos y preparamos nuestra base de datos de aceitunas. Recordad que distinguir entre variedades es muy importante:
# https://www.aceitesdeolivadeespana.com/la-importancia-de-las-variedades/

# %%
#@title Desarga y descompresión de datos
data_id = "variedades" #@param ["variedades", "olivenet"]

correspond = {'variedades': '1nM-EhT6ejaYtDbAvm0kbNScd6hyYzKsS', 
              'olivenet': '1-LFuqLydW7zwEFbaci54SJKTWzNIr9OU'}
if data_id=='variedades':
  # !wget "https://4mosoft.com/unia/uploads/variedades.zip"
elif data_id=='olivenet':
  # !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1-LFuqLydW7zwEFbaci54SJKTWzNIr9OU' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1-LFuqLydW7zwEFbaci54SJKTWzNIr9OU" -O 'olivenet.zip' && rm -rf /tmp/cookies.txt
else:
  print('wrong id')
# !mkdir data
# !unzip {data_id}.zip -d data
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0037_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0037_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0038_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0038_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0038_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0041_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0041_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0042_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0044_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0044_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0044_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0044_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0044_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0048_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0048_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0048_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0048_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0060_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0060_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0060_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0061_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0061_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0061_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0061_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0061.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0069_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0069_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0069_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0070_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0070_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0070_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0070_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0073_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0073_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0073_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0073.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0075.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0076_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0076_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0076_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0076.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0077_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0077_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0077_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0077_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0077.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0080.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0085_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0085_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0085_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0085.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0087_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0087_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0087_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0087_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0087.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0105_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0105_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0105_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0105.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0114_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0114_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0114_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0115_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0115_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0115_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0115_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0115.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0122_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0122_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0122_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0122_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0125_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0125.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0127_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0127_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0127_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0127.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0129.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0139_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0139_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0139_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0142_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0142_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0142_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0142_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0146_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0146_2.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0146_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0149_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0149_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0149_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0149_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0150.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0154.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0172_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0172.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0175_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0175_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0175.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0176_1.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0176_3.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0176_4.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0176_6.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0176.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0195_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0195_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0199_5.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0199_7.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/exPicual_0199.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0001.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0002.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0004.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0011.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0013.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0014.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0015.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0018.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0019.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0020.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0024.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0027.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0028.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0029.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0031.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0032.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0033.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0034.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0035.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0039.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0040.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0041.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0042.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0047.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0052.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0053.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0056.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0057.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0059.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0061.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0063.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0067.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0068.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0071.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0072.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0075.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0078.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0079.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0081.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0082.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0083.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0084.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0088.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0089.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0091.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0092.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0101.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0103.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0104.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0106.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0109.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0110.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0112.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0114.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0115.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0116.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0118.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0120.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0121.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0124.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0128.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0134.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0135.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0136.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0139.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0144.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0146.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0148.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0149.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0150.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0151.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0152.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0155.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0157.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0158.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0161.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0162.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0163.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0164.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0167.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0168.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0171.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0174.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0176.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0178.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0180.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0181.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0187.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0191.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0192.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0197.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0199.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0200.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0203.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0205.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0206.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0209.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0211.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0213.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0214.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0218.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0219.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0222.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0223.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0228.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0229.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0231.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0232.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0236.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0241.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0248.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0252.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0253.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0254.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0259.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0261.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0264.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0266.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0268.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0269.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0270.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0273.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0274.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0276.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0278.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0279.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0282.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0283.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0285.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0287.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0291.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0292.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0293.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0296.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0298.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0300.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0301.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0302.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0303.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0304.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0307.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0313.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0315.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0316.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0318.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0319.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0321.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0322.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0323.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0324.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0325.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0327.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0328.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0329.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0332.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0333.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0335.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0336.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0337.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0338.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0339.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0340.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0343.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0346.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0347.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0348.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0353.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0355.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0367.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0369.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0371.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0372.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0373.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0375.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0377.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0378.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0379.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0380.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0381.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0384.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0385.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0386.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0387.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0388.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0390.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0392.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0395.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0396.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0398.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0400.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0402.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0403.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0404.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0407.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0408.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0409.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0411.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0415.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0416.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0418.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0419.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0420.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0421.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0422.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0423.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0426.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0427.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0431.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0432.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0434.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0435.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0436.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0437.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0438.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0439.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0440.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0441.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0443.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0445.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0446.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0447.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0448.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0450.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0451.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0453.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0455.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0456.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0458.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0460.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0463.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0465.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0466.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0471.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0474.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0478.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0480.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0482.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0484.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0486.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0488.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0490.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0491.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0497.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0502.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0506.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0510.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0511.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0512.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0513.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0514.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0516.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0518.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0519.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0520.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0525.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0527.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0531.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0540.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0541.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0542.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0543.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0545.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0546.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0551.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0552.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0553.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0554.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0557.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0559.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0560.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0561.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0562.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0563.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0566.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0568.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0569.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0571.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0572.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0573.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0575.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0576.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0577.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0579.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0581.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0582.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0586.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0587.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0588.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0589.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0590.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0593.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0596.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0598.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0601.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0602.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0604.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0607.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0608.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0609.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0613.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0614.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0615.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0616.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0622.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0623.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0624.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0631.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0633.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0637.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0640.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0641.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0642.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0644.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0648.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0649.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0651.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0652.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0656.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0657.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0658.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0659.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0661.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0662.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0663.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0665.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0666.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0668.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0670.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0671.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0672.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0675.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0677.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0681.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0684.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0686.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0688.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0690.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0691.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0693.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0694.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0695.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0696.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0698.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0701.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0703.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0704.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0705.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0707.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0708.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0709.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0711.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0719.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0722.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0726.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0727.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0729.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0730.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0731.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0732.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0735.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0736.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0737.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0738.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0741.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0742.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0746.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0747.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0749.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0750.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0752.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0753.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0754.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0755.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0757.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0758.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0760.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0761.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0762.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0765.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0771.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0773.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0774.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0775.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0776.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0777.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0779.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0783.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0784.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0786.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0788.TIFF.JPG
#   inflating: data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE/Picual/Picual_0789.TIFF.JPG
# ...
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0167.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0168.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0169.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0170.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0173.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0174.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0175.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0176.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0177.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0178.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0179.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0181.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0182.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0183.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0184.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0185.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0186.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0190.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0191.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0193.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0195.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0196.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0197.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0198.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0199.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Lechin/Lechin_0200.TIFF.JPG
#    creating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0019.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0021.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0022.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0023.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0024.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0025.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0026.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0027.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0029.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0030.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0031.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0032.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0033.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0035.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0037.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0038.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0039.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0041.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0042.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0043.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0044.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0045.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0046.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0047.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0048.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0050.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0051.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0052.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0053.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0054.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0055.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0056.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0058.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0059.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0060.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0061.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0062.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0063.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0066.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0067.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0068.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0069.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0070.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0071.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0072.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0073.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0074.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0076.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0077.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0078.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0079.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0080.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0081.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0082.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0083.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0084.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0085.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0087.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0088.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0089.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0091.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0092.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0094.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0096.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0097.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0098.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0099.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0101.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0102.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0104.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0105.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0106.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0107.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0108.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0109.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0110.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0112.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0114.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0115.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0116.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0118.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0120.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0121.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0122.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0123.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0124.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0125.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0127.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0128.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0129.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0130.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0131.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0132.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0133.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0134.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0135.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0136.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0137.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0138.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0139.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0140.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0141.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0143.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0144.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0147.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0148.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0149.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0150.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0152.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0153.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0154.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0155.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0156.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0157.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0158.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0159.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0160.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0161.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0162.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0163.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0164.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0165.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0166.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0168.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0169.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0170.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0173.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0174.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0175.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0176.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0177.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0178.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0179.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0180.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0181.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0182.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0183.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0184.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0185.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0186.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0187.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0188.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0189.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0191.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0194.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0196.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0197.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0198.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0199.TIFF.JPG
#   inflating: data/Variedades-JPG/VALIDACION_45_GREYSCALE/Changlot/Changlot_0200.TIFF.JPG

# %% [markdown]
# ## Creación del experimento
# Antes de comenzar, es fundamental pensar bien qué queremos hacer. Comenzar a escribir código sin más es garantía de fallo. Así pues, tenemos que tener muy claras las partes fundamentales de un experimento de deep learning:
# - Carga de los datos
# - Especificar los hiperparámetros
# - Creación de los modelo
# - Bucles de entrenamiento, validación
# - Análisis de los resultados
#
# Si somos metódicos, evitaremos errores que pueden ser debidos a descuidos. Una buena práctica es definir los hiperparámetros en el mismo lugar:

# %%
# Hiperparámetros:
BATCH_SIZE=64  # Le damos lotes de 128 imágenes para que no se sobrecargue el procesador.
LR = 1e-5
IMAGE_SIZE = (256,256)
N_EPOCHS = 100 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # device va a ser la GPU si hay una GPU disponible, y si no, CPU

# %% [markdown]
# Al especificar ya algunos datos del entrenamiento, como el caso del `batch_size`, podemos generar los dataloaders; un tipo de objeto que nos permitirá "muestrear" el dataset en *batches*, y de esa forma realizar el forward pass en el bucle de entrenamiento. También realizaremos algunas transformaciones (preprocesamiento), como:
# - remuestrear (reducir el tamaño)
# - normalizar la intensidad
# - transformar a tensor de pytorch
#
# Y otras opciones que habitualmente se usan para *data augmentation* como rotar o escalar aleatoriamente en el conjunto de entrenamiento. Así que vamos a crear, en primer lugar, el dataset y dataloader de entrenamiento:

# %%
train_transforms = T.Compose([T.Grayscale(),
                                 T.Resize(size=IMAGE_SIZE),
                                 T.ToTensor()])

# Creamos los objetos datasets a partir de un ImageFolder de torchvision:
data_train = ImageFolder('./data/Variedades-JPG/ENTRENAMIENTO_45_GREYSCALE', transform=train_transforms) # /content/data
train_loader = DataLoader(data_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)

# Mostramos el batch de entrenamiento:
print(f'Encontradas {len(data_train.classes)} clases: {data_train.class_to_idx}')
images, labels = next(iter(train_loader))
plt.imshow(make_grid(images).permute(1, 2, 0))
# Out:
# Encontradas 7 clases: {'Arbequina': 0, 'Arbosana': 1, 'Changlot': 2, 'Lechin': 3, 'Ocal': 4, 'Picual': 5, 'Verdial': 6}

# %% [markdown]
# Y a continuación el de validación:

# %%
val_transforms = T.Compose([T.Grayscale(),
                            T.Resize(size=IMAGE_SIZE),
                            T.ToTensor()])

data_val = ImageFolder('./data/Variedades-JPG/VALIDACION_45_GREYSCALE', transform=val_transforms) # /content/data
val_loader = DataLoader(data_val, batch_size=BATCH_SIZE, shuffle=False)

# Mostramos el batch de entrenamiento:
images, labels = next(iter(val_loader))
print(f'Encontradas {len(data_val.classes)} clases: {data_val.class_to_idx}')
plt.imshow(make_grid(images).permute(1, 2, 0))
# Out:
# Encontradas 7 clases: {'Arbequina': 0, 'Arbosana': 1, 'Changlot': 2, 'Lechin': 3, 'Ocal': 4, 'Picual': 5, 'Verdial': 6}

# %% [markdown]
# ## Creación del modelo a usar
#
# A continuación, queremos especificar el modelo de aprendizaje que vamos a utilizar. Para esta práctica vamos a comenzar con Alexnet. Recordemos su estructura:
# ![Scheme-of-the-AlexNet-network-used.png](data:image/png;base64,...)

# %% [markdown]
# Podemos identificar 5 capas convolucionales y 3 capas fully connected, como las del perceptrón. La estructura sería la siguiente:
# - Conv1: 64 filtros de 5x5 sin stride
# - Maxpool1: stride 2
# - Conv2: 256 filtros de 5x5 sin stride
# - Maxpool2: stride 2
# - Conv3: 384 filtros de 3x3 sin stride
# - Conv4: 384 filtros de 3x3 sin stride
# - Conv5: 192 filtros de 3x3 sin stride
# - Reestructuración de los datos a un vector
# - Fc1: Capa fully connected con 4096 neuronas
# - Fc2: Capa fully connected con 4096 neuronas
# - Fc3: Capa fully connected con N neuronas
#
# Donde ese N es el número de clases. En nuestro caso, serán 2 para olivenet (aceituna, no aceituna) o 7 para el dataset de variedades de aceituna (arbequina, arbosana, changlot, lechin, ocal, picual, verdial).

# %%
class AlexNet(nn.Module):
  def __init__(self, n_classes=2, input_size=48):
    super(AlexNet, self).__init__() # esta linea es siempre necesaria

    # Red convolucional
    self.conv1 = nn.Conv2d(1,out_channels=64, kernel_size=(5,5), stride=1)  # Primera capa convolucional
    self.max1  = nn.MaxPool2d(kernel_size=4)
    self.conv2 = nn.Conv2d(64, 256, kernel_size=5, stride=1)  # Segunda capa convolucional
    self.max2  = nn.MaxPool2d(kernel_size=4)
    self.conv3 = nn.Conv2d(256, 384, kernel_size=3, stride=1)  # Tercera capa convolucional
    self.conv4 = nn.Conv2d(384, 384, kernel_size=3, stride=1)  # Cuarta capa convolucional
    self.conv5 = nn.Conv2d(384, 192, kernel_size=3, stride=1)  # Quinta capa convolucional 

    # Capas fully connected
    self.fc1 = nn.LazyLinear(512)  
    self.fc2 = nn.LazyLinear(512)
    self.fc3 = nn.LazyLinear(n_classes)
   

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = self.max1(x)
    x = F.relu(self.conv2(x))
    x = self.max2(x)
    x = F.relu(self.conv3(x))
    x = F.relu(self.conv4(x))
    x = F.relu(self.conv5(x))
    x = x.view((x.shape[0], -1)) # x.shape es el tamaño del batch (batch_size)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    return F.softmax(self.fc3(x), dim=1)

# Prueba
model = AlexNet(n_classes=7, input_size=IMAGE_SIZE[0])
model(images[:1]).shape  # no pone [0] porque si no le quita una dimensión. En cambio, si pone :1, lo respeta
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# torch.Size([1, 7])

# %% [markdown]
# Alternativamente, podemos utilizar la sintaxis secuencial para generar el mismo modelo de forma más rápida. Además, es más sencillo para redes grandes compuestas de muchos bloques y muchas capas:

# %%
class AlexNet2(nn.Module):
  def __init__(self, n_classes=2, input_size=48):
    super(AlexNet2, self).__init__() # esta linea es siempre necesaria
    
  def forward(self, x):

# Prueba
model = AlexNet2(n_classes=7, input_size=IMAGE_SIZE[0])
model(images).shape

# %% [markdown]
# ## Bucle de entrenamiento
#
# Para facilitarnos la vida vamos a crear una función `train()` que, dados un modelo, el optimizador, la función de loss y el número de epochs, entrene la red y nos devuelva un diccionario con el historial de training loss:

# %%
def train(model, optimizer, loss_fn, N_EPOCHS=2):
  train_history={'loss': [], 'acc': []}
  max_perf = 1e11
  for e in range(N_EPOCHS):
    train_loss = 0.0 # el loss en cada epoch de entrenamiento
    train_acc = 0.0 # el accuracy de cada epoch
    total_train=0  # número de lotes

    for ims, lbs in train_loader:
      total_train += 1
      ims = ims.to(device) # pasamos a cuda
      lbs = lbs.to(device) # pasamos a cuda

      output = model(ims) # forward pass
      loss = loss_fn(output, lbs) # calculamos el loss
      loss.backward()# backward pass
      optimizer.step() # optimización 

      train_loss += loss # acumulación para mostrar

      # predicción de la red:
      _, predicted = torch.max(output, 1) 
      train_acc += torch.sum(predicted==lbs)/lbs.shape[0] # y acumulamos el número de correctos
    ls_val = (train_loss/total_train).detach().cpu().numpy()
    acc_val = (train_acc/total_train).detach().cpu().numpy()
    train_history['loss'].append(ls_val)
    train_history['acc'].append(acc_val)
    print(f'Epoch {e}: Loss: {train_loss/total_train}, acc: {train_acc/total_train}')
    
  return train_history

# %% [markdown]
# Ahora definiremos nuestra red, el optimizador y la función de pérdida:

# %%
model = AlexNet(n_classes=7, input_size=IMAGE_SIZE[0])
model = model.to(device) # pasamos a cuda
# model = torch.load('model_aceitunas_2207_3360e.mdl')
loss_fn = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=1e-5, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-6)  # Adam es un optimizador que converge rápido.
# optimizer = optim.SGD(model.parameters(), lr=1e-6, momentum=0.9)
history = train(model, optimizer, loss_fn, 200)
# Out:
# Epoch 0: Loss: 1.9452528953552246, acc: 0.15000160038471222
# Epoch 1: Loss: 1.9257686138153076, acc: 0.2852715849876404
# Epoch 2: Loss: 1.8807553052902222, acc: 0.26628103852272034
# Epoch 3: Loss: 1.8513270616531372, acc: 0.26767846941947937
# Epoch 4: Loss: 1.837205171585083, acc: 0.2822954058647156
# Epoch 5: Loss: 1.8048776388168335, acc: 0.33368000388145447
# Epoch 6: Loss: 1.7974873781204224, acc: 0.34761691093444824
# Epoch 7: Loss: 1.7979086637496948, acc: 0.34783825278282166
# Epoch 8: Loss: 1.7960704565048218, acc: 0.3531292676925659
# Epoch 9: Loss: 1.7825367450714111, acc: 0.3729545474052429
# Epoch 10: Loss: 1.7894755601882935, acc: 0.36692216992378235
# Epoch 11: Loss: 1.7906705141067505, acc: 0.3698476552963257
# Epoch 12: Loss: 1.7784315347671509, acc: 0.38279515504837036
# Epoch 13: Loss: 1.7824352979660034, acc: 0.3794296085834503
# Epoch 14: Loss: 1.7714616060256958, acc: 0.39019832015037537
# Epoch 15: Loss: 1.7845648527145386, acc: 0.37781351804733276
# Epoch 16: Loss: 1.7763580083847046, acc: 0.387179434299469
# Epoch 17: Loss: 1.7834243774414062, acc: 0.3795095980167389
# Epoch 18: Loss: 1.7724263668060303, acc: 0.3910703659057617
# Epoch 19: Loss: 1.7673029899597168, acc: 0.3960493505001068
# Epoch 20: Loss: 1.7691162824630737, acc: 0.3946359157562256
# Epoch 21: Loss: 1.75449538230896, acc: 0.4096395671367645
# Epoch 22: Loss: 1.7752881050109863, acc: 0.38829952478408813
# Epoch 23: Loss: 1.7552895545959473, acc: 0.4089515209197998
# Epoch 24: Loss: 1.7686879634857178, acc: 0.3957560062408447
# Epoch 25: Loss: 1.7484097480773926, acc: 0.41656532883644104
# Epoch 26: Loss: 1.7610530853271484, acc: 0.40328449010849
# Epoch 27: Loss: 1.7521597146987915, acc: 0.4122450649738312
# Epoch 28: Loss: 1.7610193490982056, acc: 0.4039511978626251
# Epoch 29: Loss: 1.7520142793655396, acc: 0.41278910636901855
# Epoch 30: Loss: 1.7560831308364868, acc: 0.4087941646575928
# Epoch 31: Loss: 1.7531766891479492, acc: 0.4116823375225067
# Epoch 32: Loss: 1.7480838298797607, acc: 0.4168986678123474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6be89d64ebc0> in <module>
#       6 optimizer = optim.Adam(model.parameters(), lr=1e-6)  # Adam es un optimizador que converge rápido.
#       7 # optimizer = optim.SGD(model.parameters(), lr=1e-6, momentum=0.9)
# ----> 8 history = train(model, optimizer, loss_fn, 200)
#
# <ipython-input-9-4dcd8c269ff2> in train(model, optimizer, loss_fn, N_EPOCHS)
#       7     total_train=0  # número de lotes
#       8
# ----> 9     for ims, lbs in train_loader:
#      10       total_train += 1
#      11       ims = ims.to(device) # pasamos a cuda
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1357
#    1358             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359             idx, data = self._get_data()
#    1360             self._tasks_outstanding -= 1
#    1361             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1323         else:
#    1324             while True:
# -> 1325                 success, data = self._try_get_data()
#    1326                 if success:
#    1327                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1161         #   (bool: whether successfully get data, any: data if successful else None)
#    1162         try:
# -> 1163             data = self._data_queue.get(timeout=timeout)
#    1164             return (True, data)
#    1165         except Exception as e:
#
# /usr/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.monotonic()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# /usr/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /usr/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     919
#     920             while True:
# --> 921                 ready = selector.select(timeout)
#     922                 if ready:
#     923                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# Para ver como se comporta sobre el conjunto de test, creamos otra función que nos ayude

# %%
def test(model, optimizer, loss_fn):
  with torch.no_grad():
    test_history={'loss': [], 'acc': [], 'ytrue': [], 'preds': []}

    for ims, lbs in val_loader:
      ims = ims.to(device) # pasamos a cuda
      lbs = lbs.to(device) # pasamos a cuda

      output = model(ims) # forward pass
      loss = loss_fn(output, lbs) # calculamos el loss
      test_history['loss'].append(loss.item()) # acumulación para mostrar

      # predicción de la red:
      _, predicted = torch.max(output, 1) 
      test_history['ytrue'].append(lbs.detach().cpu().numpy())
      test_history['preds'].append(predicted.detach().cpu().numpy())
      test_history['acc'].append((predicted==lbs).detach().cpu().numpy().mean()) # y acumulamos el número de correctos
    
    loss_sum = sum(test_history['loss'])/len(test_history['loss'])
    acc_sum = sum(test_history['acc'])/len(test_history['acc'])
    print(f'Validacion: Loss: {loss_sum}, acc: {acc_sum}')
  return test_history

# %%
test_outputs = test(model, optimizer, loss_fn)
# Out:
# Validacion: Loss: 1.7158274931066178, acc: 0.4494485294117647

# %%
# Esto es para guardar y cargar el modelo
torch.save(model, 'model_clase.mdl')
model = torch.load('model_clase.mdl')

# %% [markdown]
# ## Interpretando los resultados
# En general, es habitual dejarlo aquí. Tenemos unos números muy buenos, no? Pues ale, a otra cosa. Sin embargo, a partir de estas redes neuronales ya entrenadas podemos extraer mucha más información. Para empezar, un aspecto clave son las curvas de entrenamiento:

# %%
history['loss'] = [el.item() for el in history['loss']]

# %%
plt.plot(history['loss'])

# %% [markdown]
# Estas curvas nos muestran como el loss va decreciendo a lo largo de las diferentes epochs. Podemos hacer lo mismo para el historial del accuracy (que no tiene por qué ser igual que el *loss*):

# %%
plt.plot(history['acc'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6c0e310b6202> in <module>
# ----> 1 plt.plot(history['acc'])
#
# NameError: name 'history' is not defined

# %% [markdown]
# Asimismo, otro indicador acerca de las predicciones de nuestro modelo es la "matriz de confusión" (lo encontraréis como *confussion matrix*). En este caso vamos a utilizar una librería bien conocida por los

# %%
import numpy as np 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = np.concatenate(test_outputs['ytrue'])
y_pred = np.concatenate(test_outputs['preds'])

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data_train.classes)
disp.plot(xticks_rotation=45)

# %% [markdown]
# ¿Qué conclusiones podemos extraer de aquí?

# %% [markdown]
# ## Transfer learning
# Entrenar una red es costoso en tiempo y recursos. Hoy en día existen miles de redes ya entrenadas que podemos utilizar para nuestros proyectos, tan solo cambiando su propósito. A este procedimiento se conoce como *Transfer Learning*.

# %%
from types import new_class
import torchvision
model = torchvision.models.squeezenet1_1(pretrained=True)
old_input_layer = model.features[0]
model.features[0] = nn.Conv2d(1, old_input_layer.out_channels, 
                                kernel_size=old_input_layer.kernel_size,
                                stride = old_input_layer.stride,
                                padding=old_input_layer.padding)
state_dict = old_input_layer.state_dict()
state_dict['weight'] = state_dict['weight'][:,0:1]
model.features[0].load_state_dict(state_dict)
for par in model.features.parameters():
    par.requires_grad=False

model.classifier = nn.Sequential(
            nn.Dropout(p=0.5, inplace=False),
            nn.Conv2d(512, 7, kernel_size=(1, 1), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(output_size=(1, 1))
  )
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=SqueezeNet1_1_Weights.IMAGENET1K_V1`. You can also use `weights=SqueezeNet1_1_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
#   0%|          | 0.00/4.73M [00:00<?, ?B/s]

# %%
model = model.to(device) # pasamos a cuda
# model = torch.load('model_aceitunas_2207_3360e.mdl')
loss_fn = nn.CrossEntropyLoss()
# optimizer = optim.SGD(model.parameters(), lr=1e-5, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# optimizer = optim.SGD(model.parameters(), lr=1e-6, momentum=0.9)
history_2 = train(model, optimizer, loss_fn, 20)
# Out:
# Epoch 0: Loss: 1.7989033460617065, acc: 0.2837488055229187
# Epoch 1: Loss: 1.6697629690170288, acc: 0.3350374400615692
# Epoch 2: Loss: 1.6221688985824585, acc: 0.32721826434135437
# Epoch 3: Loss: 1.5712172985076904, acc: 0.39152640104293823
# Epoch 4: Loss: 1.560198426246643, acc: 0.38255247473716736
# Epoch 5: Loss: 1.4868346452713013, acc: 0.44158291816711426
# Epoch 6: Loss: 1.4555938243865967, acc: 0.4380493462085724
# Epoch 7: Loss: 1.4710372686386108, acc: 0.41680002212524414
# Epoch 8: Loss: 1.4331879615783691, acc: 0.41847744584083557
# Epoch 9: Loss: 1.403721809387207, acc: 0.46088817715644836
# Epoch 10: Loss: 1.4195382595062256, acc: 0.45718395709991455
# Epoch 11: Loss: 1.3932901620864868, acc: 0.4715368449687958
# Epoch 12: Loss: 1.4063925743103027, acc: 0.4551144540309906
# Epoch 13: Loss: 1.3589671850204468, acc: 0.47358763217926025
# Epoch 14: Loss: 1.406589150428772, acc: 0.4645417332649231
# Epoch 15: Loss: 1.3536814451217651, acc: 0.4890099763870239
# Epoch 16: Loss: 1.3896949291229248, acc: 0.46740591526031494
# Epoch 17: Loss: 1.366042137145996, acc: 0.48058009147644043
# Epoch 18: Loss: 1.3524740934371948, acc: 0.4849323630332947
# Epoch 19: Loss: 1.3744615316390991, acc: 0.4761984646320343

# %%
model = torch.load('squeeze_1208_34e.mdl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-c67bf4d49a79> in <module>
# ----> 1 model = torch.load('squeeze_1208_34e.mdl')
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'squeeze_1208_34e.mdl'

# %%
test_outputs = test(model, optimizer, loss_fn)
# Out:
# Validacion: Loss: 2.037054847268497, acc: 0.16798642533936653

# %%
import numpy as np 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = np.concatenate(test_outputs['ytrue'])
y_pred = np.concatenate(test_outputs['preds'])

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data_train.classes)
disp.plot(xticks_rotation=45)
